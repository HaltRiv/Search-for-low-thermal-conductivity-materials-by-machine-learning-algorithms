# %%
from mp_api.client import MPRester
import pandas
import pymatgen

# %%
m = MPRester(api_key="f3pdksiwKJRwdeKTjBqUC1ODnA1OTf4W")
data = m.get_phonon_dos_by_material_id(material_id="mp-11714")
# Out:
# E:\Programowanie\Python\envs\SFLTCMBMLA\lib\site-packages\mp_api\client\mprester.py:139: UserWarning: mpcontribs-client not installed. Install the package to query MPContribs data, or construct pourbaix diagrams: 'pip install mpcontribs-client'
#   warnings.warn(
# Retrieving PhononBSDOSDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
print(data)
# Out:
# Complete phonon DOS for Full Formula (Si4 C4)
# Reduced Formula: SiC
# abc   :   3.078662   3.078662  10.077922
# angles:  90.000000  90.000000 120.000000
# pbc   :       True       True       True
# Sites (8)
#   #  SP            a          b         c
# ---  ----  ---------  ---------  --------
#   0  Si     0.333333   0.666667  0.06216
#   1  Si     0.666667   0.333333  0.56216
#   2  Si    -0         -0         0.312096
#   3  Si    -0         -0         0.812096
#   4  C      0.333333   0.666667  0.250191
#   5  C      0.666667   0.333333  0.750191
#   6  C     -0         -0         0.499553
#   7  C     -0         -0         0.999553

# %%
help(MPRester)
# Out:
# Help on class MPRester in module mp_api.client.mprester:
#
# class MPRester(builtins.object)
#  |  MPRester(api_key=None, endpoint='https://api.materialsproject.org/', notify_db_version=False, include_user_agent=True, monty_decode: bool = True, use_document_model: bool = True)
#  |
#  |  Access the new Materials Project API.
#  |
#  |  Methods defined here:
#  |
#  |  __enter__(self)
#  |      Support for "with" context.
#  |
#  |  __exit__(self, exc_type, exc_val, exc_tb)
#  |      Support for "with" context.
#  |
#  |  __getattr__(self, attr)
#  |
#  |  __init__(self, api_key=None, endpoint='https://api.materialsproject.org/', notify_db_version=False, include_user_agent=True, monty_decode: bool = True, use_document_model: bool = True)
#  |      Args:
#  |          api_key (str): A String API key for accessing the MaterialsProject
#  |              REST interface. Please obtain your API key at
#  |              https://next-gen.materialsproject.org/api. If this is None,
# ...

# %%
data_set = pandas.read_excel("E:\Magisterka\Dane\data_1.0.xlsx")
data_set
# Out:
#     Compound        ID  Mean atomic weight  \
# 0          C  990448.0             12.0107
# 1        SiC   11714.0             20.0500
# 2         Si     149.0             28.0900
# 3         Ge       NaN             72.6400
# 4         BN     984.0             12.4100
# ..       ...       ...                 ...
# 231    Ga2O3    1243.0                 NaN
# 232    Si3N4    2245.0                 NaN
# 233     SiO2    7000.0                 NaN
# 234     SnO2     856.0                 NaN
# 235   ZnGeP2    4524.0                 NaN
#
#      Lattice thermal conductivity (Experimental) at 300 K, W/(m K)
# 0                                               2300.0
# 1                                                490.0
# 2                                                157.6
# 3                                                 60.0
# 4                                                760.0
# ..                                                 ...
# ...

# %%
data_set = data_set.dropna()
data_set
# Out:
#     Compound        ID  Mean atomic weight  \
# 0          C  990448.0             12.0107
# 1        SiC   11714.0             20.0500
# 2         Si     149.0             28.0900
# 4         BN     984.0             12.4100
# 5         BP    1479.0             20.8900
# 6        AlN     661.0             20.4950
# 7        AlP    1550.0             28.9800
# 8       AlAs    2172.0             50.9500
# 9       AlSb    2624.0             74.3700
# 10       GaN     804.0             83.7300
# 11       GaP    2490.0             50.3500
# 14       InP   20351.0             72.8950
# 19      CdTe     406.0            120.0050
# 20      CdSe    1070.0             95.6850
# 21       CdS     672.0             72.2400
# 22      ZnTe    2176.0             96.4950
# 23      ZnSe    1190.0             72.1750
# 24       ZnS   10695.0             48.7300
# 25    CuAlS2    4979.0             38.6650
# 26    CuGaS2    5238.0             49.3500
# 27   CuAlSe2    8016.0             62.1125
# ...

# %%
data_set.shape
# Out:
# (60, 4)

# %%
data_set['ID'] = data_set['ID'].astype(int)
data_set
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18120\2133846916.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_set['ID'] = data_set['ID'].astype(int)
#     Compound      ID  Mean atomic weight  \
# 0          C  990448             12.0107
# 1        SiC   11714             20.0500
# 2         Si     149             28.0900
# 4         BN     984             12.4100
# 5         BP    1479             20.8900
# 6        AlN     661             20.4950
# 7        AlP    1550             28.9800
# 8       AlAs    2172             50.9500
# 9       AlSb    2624             74.3700
# 10       GaN     804             83.7300
# 11       GaP    2490             50.3500
# 14       InP   20351             72.8950
# ...

# %%
new_data_set = [[],[],[]]

# %%
for i in data_set['Compound']:
    new_data_set[0].append(i)

for i in data_set["ID"]:
    new_data_set[1].append("mp-"+str(i))

# %%
new_data_set
# Out:
# [['C',
#   'SiC',
#   'Si',
#   'BN',
#   'BP',
#   'AlN',
#   'AlP',
#   'AlAs',
#   'AlSb',
#   'GaN',
#   'GaP',
#   'InP',
#   'CdTe',
#   'CdSe',
#   'CdS',
#   'ZnTe',
#   'ZnSe',
#   'ZnS',
#   'CuAlS2',
#   'CuGaS2',
#   'CuAlSe2',
#   'CuAlTe2',
#   'AgInS2',
#   'AgGaS2',
#   'Cu2SiS3',
#   'Ag2S',
#   'Ag2Se',
#   'Li2O ',
#   'Li2S ',
#   'Li2Se',
#   'Li2Te',
#   'LiH',
#   'LiF',
#   'NaF',
#   'NaCl',
#   'NaBr',
#   'NaI',
#   'KCl',
#   'KBr',
#   'RbCl',
#   'RbBr',
#   'RbI',
#   'AgCl',
#   'MgO',
#   'CaO',
#   'SrO',
#   'BaO',
#   'SnSe',
#   'GeTe',
#   'PbTe',
#   'PbSe',
#   'PbS',
#   'Ag8GeS6',
#   'MgAl2O4',
#   'TiCoSb',
#   'NbFeSb',
#   'VFeSb',
#   'ZrNiSn',
#   'ZrCoBi',
#   'TiNiSn'],
#  ['mp-990448',
#   'mp-11714',
#   'mp-149',
#   'mp-984',
#   'mp-1479',
#   'mp-661',
#   'mp-1550',
#   'mp-2172',
#   'mp-2624',
#   'mp-804',
#   'mp-2490',
#   'mp-20351',
#   'mp-406',
#   'mp-1070',
#   'mp-672',
#   'mp-2176',
#   'mp-1190',
#   'mp-10695',
# ...

# %%
for i in new_data_set[1]:
    m.get_phonon_dos_by_material_id(material_id=i)
new_data_set
# Out:
# E:\Programowanie\Python\envs\SFLTCMBMLA\lib\site-packages\mp_api\client\mprester.py:139: UserWarning: mpcontribs-client not installed. Install the package to query MPContribs data, or construct pourbaix diagrams: 'pip install mpcontribs-client'
#   warnings.warn(
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# E:\Programowanie\Python\envs\SFLTCMBMLA\lib\site-packages\mp_api\client\core\client.py:906: UserWarning: Document primary key has changed from mp-990448 to mp-990448, returning data for mp-990448 in phonon route.
#   warnings.warn(
# ---------------------------------------------------------------------------
# MPRestError                               Traceback (most recent call last)
# File E:\Programowanie\Python\envs\SFLTCMBMLA\lib\site-packages\mp_api\client\core\client.py:894, in BaseRester.get_data_by_id(self, document_id, fields)
#     893 try:
# ...

# %%
m = MPRester(api_key="f3pdksiwKJRwdeKTjBqUC1ODnA1OTf4W")
data = m.get_phonon_dos_by_material_id(material_id="mp-11714")
# Out:
# E:\Programowanie\Python\envs\SFLTCMBMLA\lib\site-packages\mp_api\client\mprester.py:139: UserWarning: mpcontribs-client not installed. Install the package to query MPContribs data, or construct pourbaix diagrams: 'pip install mpcontribs-client'
#   warnings.warn(
# Retrieving PhononBSDOSDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
print(data)

# %%
from list_of_id import id
id
mp_id = []

for i in id:
    x = "mp-"+i

    mp_id.append(x)
mp_id
# Out:
# Traceback (most recent call last):
#
#   File E:\Programowanie\Python\envs\SFLTCMBMLA\lib\site-packages\IPython\core\interactiveshell.py:3433 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In [14], line 1
#     from list_of_id import id
#
#   File ~\PycharmProjects\Searching_for_low_thermal_conductivity_materials\list_of_id.py:4011
# ...

# %%
m = MPRester(api_key="f3pdksiwKJRwdeKTjBqUC1ODnA1OTf4W")
data = []
for i in mp_id:
    try:
        data.append(m.get_phonon_dos_by_material_id(material_id=i))
    except: "MPRestError"
# Out:
# E:\Programowanie\Python\envs\SFLTCMBMLA\lib\site-packages\mp_api\client\mprester.py:146: UserWarning: mpcontribs-client not installed. Install the package to query MPContribs data, or construct pourbaix diagrams: 'pip install mpcontribs-client'
#   warnings.warn(
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# E:\Programowanie\Python\envs\SFLTCMBMLA\lib\site-packages\mp_api\client\core\client.py:862: UserWarning: Document primary key has changed from mp-25 to mp-25, returning data for mp-25 in phonon route.
#   warnings.warn(
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# E:\Programowanie\Python\envs\SFLTCMBMLA\lib\site-packages\mp_api\client\core\client.py:862: UserWarning: Document primary key has changed from mp-39 to mp-39, returning data for mp-39 in phonon route.
#   warnings.warn(
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
data[0]

# %%
print(m.get_phonon_dos_by_material_id(material_id="mp-743"))
# Out:
# Retrieving PhononBSDOSDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Complete phonon DOS for Full Formula (Rb2 N6)
# Reduced Formula: RbN3
# abc   :   5.796157   5.796157   5.796157
# angles: 114.488096 114.488096  99.845480
# pbc   :       True       True       True
# Sites (8)
#   #  SP         a       b         c
# ---  ----  ------  ------  --------
#   0  Rb    0.25    0.25    0
#   1  Rb    0.75    0.75    0
#   2  N     1       0.5     0.5
#   3  N     0.5     1       0.5
#   4  N     0.3663  0.1337  0.5
#   5  N     0.8663  0.3663  0.232601
#   6  N     0.1337  0.6337  0.767399
#   7  N     0.6337  0.8663  0.5

# %%
print(data[4])
# Out:
# Complete phonon DOS for Full Formula (Ba2 S6)
# Reduced Formula: BaS3
# abc   :   6.810985   6.810985   4.111194
# angles:  90.000000  90.000000  90.000000
# pbc   :       True       True       True
# Sites (8)
#   #  SP          a        b         c
# ---  ----  -------  -------  --------
#   0  Ba    0.5      0.5      0
#   1  Ba    0        0        0
#   2  S     0.81848  0.31848  0.483393
#   3  S     0.31848  0.18152  0.516607
#   4  S     0        0.5      0.208776
#   5  S     0.5      0        0.791224
#   6  S     0.18152  0.68152  0.483393
#   7  S     0.68152  0.81848  0.516607

# %%
import pandas as pd

data_series = pd.Series(data)
data_series
# Out:
# 0      Complete phonon DOS for Full Formula (Si2)\nRe...
# 1      Complete phonon DOS for Full Formula (B12)\nRe...
# 2      Complete phonon DOS for Full Formula (Si4)\nRe...
# 3      Complete phonon DOS for Full Formula (Ge3 O6)\...
# 4      Complete phonon DOS for Full Formula (Ba2 S6)\...
#                              ...
# 836    Complete phonon DOS for Full Formula (Sr2 H2 B...
# 837    Complete phonon DOS for Full Formula (Ba2 H2 B...
# 838    Complete phonon DOS for Full Formula (K2 H4 N2...
# 839    Complete phonon DOS for Full Formula (K4 H2 Br...
# 840    Complete phonon DOS for Full Formula (Rb1 H1)\...
# Length: 841, dtype: object

# %%
len(data)
# Out:
# 841

# %%
print(data_series[0])
# Out:
# Complete phonon DOS for Full Formula (Si2)
# Reduced Formula: Si
# abc   :   3.840533   3.840533   3.840533
# angles:  60.000000  60.000000  60.000000
# pbc   :       True       True       True
# Sites (2)
#   #  SP       a     b     c
# ---  ----  ----  ----  ----
#   0  Si    0.5   0.5   0.5
#   1  Si    0.75  0.75  0.75

# %%
data_series.to_csv('data_series_841', index=False)

# %%
m = MPRester(api_key="f3pdksiwKJRwdeKTjBqUC1ODnA1OTf4W")
# Out:
# E:\Programowanie\Python\envs\SFLTCMBMLA\lib\site-packages\mp_api\client\mprester.py:146: UserWarning: mpcontribs-client not installed. Install the package to query MPContribs data, or construct pourbaix diagrams: 'pip install mpcontribs-client'
#   warnings.warn(

# %%
structure = m.get_structure_by_material_id("mp-4967")
structure
# Out:
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Structure Summary
# Lattice
#     abc : 4.74587934 6.63883985 8.59634162
#  angles : 90.0 90.0 90.0
#  volume : 270.8460777520735
#       A : 4.74587934 0.0 0.0
#       B : -0.0 6.63883985 0.0
#       C : 0.0 0.0 8.59634162
#     pbc : True True True
# PeriodicSite: Mg (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
# PeriodicSite: Mg (2.3729, 0.0000, 4.2982) [0.5000, 0.0000, 0.5000]
# PeriodicSite: Mg (0.0000, 3.3194, 0.0000) [0.0000, 0.5000, 0.0000]
# PeriodicSite: Mg (2.3729, 3.3194, 4.2982) [0.5000, 0.5000, 0.5000]
# PeriodicSite: S (4.6319, 4.9791, 2.7605) [0.9760, 0.7500, 0.3211]
# PeriodicSite: S (2.2590, 1.6597, 1.5377) [0.4760, 0.2500, 0.1789]
# PeriodicSite: S (0.1140, 1.6597, 5.8359) [0.0240, 0.2500, 0.6789]
# PeriodicSite: S (2.4869, 4.9791, 7.0587) [0.5240, 0.7500, 0.8211]
# PeriodicSite: O (1.0810, 4.9791, 7.5288) [0.2278, 0.7500, 0.8758]
# ...

# %%
print(structure)
# Out:
# []

# %%
entry = m.get_entry_by_material_id("mp-4967")
print(entry)
# Out:
# Retrieving ThermoDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# [mp-4967-GGA ComputedStructureEntry - Mg4 S4 O16   (MgSO4)
# Energy (Uncorrected)     = -148.8732 eV (-6.2031  eV/atom)
# Correction               = -10.9920  eV (-0.4580  eV/atom)
# Energy (Final)           = -159.8652 eV (-6.6611  eV/atom)
# Energy Adjustments:
#   MP2020 anion correction (oxide): -10.9920  eV (-0.4580  eV/atom)
# Parameters:
#   potcar_spec            = [{'titel': 'PAW_PBE Mg_pv 06Sep2000', 'hash': 'bbcf6f81cc34a3090d483ad641178746'}, {'titel': 'PAW_PBE S 17Jan2003', 'hash': 'd368db6899d8839859bbee4811a42a88'}, {'titel': 'PAW_PBE O 08Apr2002', 'hash': '7a25bc5b9a5393f46600a4939d357982'}]
#   is_hubbard             = False
#   hubbards               = {}
#   run_type               = GGA
# Data:
#   oxide_type             = oxide
#   aspherical             = True
#   last_updated           = 2021-02-07 08:42:28.769000
#   task_id                = mp-1878576
#   material_id            = mp-4967
# ...

# %%
hermo_doc = m.get_bandstructure_by_material_id('mp-4967')
print(hermo_doc)
# Out:
# ...
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [37], line 1
# ----> 1 pymatgen.symmetry(hermo_doc)
#
# TypeError: 'module' object is not callable

# %%
from pymatgen import Structure

# Wczytaj plik POSCAR
structure = Structure.from_file("POSCAR")

# Wyświetl liczbę atomów w strukturze
num_atoms = len(structure)
print(f"Liczba atomów w strukturze: {num_atoms}")

# %%
help(pymatgen)
# Out:
# Help on package pymatgen:
#
# NAME
#     pymatgen
#
# PACKAGE CONTENTS
#     alchemy (package)
#     apps (package)
#     cli (package)
#     command_line (package)
#     core (package)
#     electronic_structure (package)
#     entries (package)
#     optimization (package)
#     phonon (package)
#     symmetry (package)
#     transformations (package)
#     util (package)
#     vis (package)
#
# SUBMODULES
#     analysis
#     io
#
# FILE
#     (built-in)

# %%
import aflow

help(aflow)
# Out:
# Help on package aflow:
#
# NAME
#     aflow
#
# PACKAGE CONTENTS
#     base
#     caster
#     control
#     entries
#     generators
#     keywords
#     msg
#     utility
#
# SUBMODULES
#     K
#
# FUNCTIONS
#     list_keywords()
#         Returns a list of all possible keywords available in the AFLOW
#         lib.
#
# FILE
#     e:\programowanie\python\envs\sfltcmbmla\lib\site-packages\aflow\__init__.py

# %%
help(aflow.search())
# Out:
# Help on Query in module aflow.control object:
#
# class Query(builtins.object)
#  |  Query(catalog=None, batch_size=100, step=1)
#  |
#  |  Represents a search againts the AFLUX API.
#  |
#  |  Args:
#  |      catalog (str): one of the catalogs supported on AFLOW: ['icsd', 'lib1',
#  |        'lib2', 'lib3']. Also supports a `list` of catalog names.
#  |      batch_size (int): number of data entries to return per HTTP request.
#  |      step (int): step size over entries.
#  |
#  |  Attributes:
#  |      filters (list): of `str` filter arguments to pass to the matchbook
#  |        section of the API request.
#  |      select (list): of :class:`aflow.keywords.Keyword` to *include* in the request.
#  |      excludes (list): of :class:`aflow.keywords.Keyword` to *exclude* in the request.
#  |      orderby (str): name of the keyword to order by. AFLUX only supports a
#  |        single order-by parameter for now.
# ...
